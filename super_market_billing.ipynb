# %%
print("Welcome to Supermarket Billing System!")

# Ask for customer details
customer_name = input("Enter your name: ")
phone_number = input("Enter your phone number: ")
while len(phone_number) != 10 or not phone_number.isdigit():
    print("Please enter a valid 10-digit phone number.")
    phone_number = input("Enter your phone number: ")

# Adding items
print("\nStart entering the items:")
items = []
total = 0

while True:
    item_name = input("Enter item name (or type 'done' to finish): ")
    if item_name.lower() == 'done':
        break
    quantity = int(input("Enter quantity for " + item_name + ": "))
    price = float(input("Enter price for " + item_name + ": "))
    
    items.append([item_name, quantity, price])
    total += quantity * price

# Discount calculation
if total > 1000:
    discount = total * 0.1  # 10% discount
elif total > 500:
    discount = total * 0.05  # 5% discount
else:
    discount = 0

final_total = total - discount

# Ask for payment method
payment_method = input("\nEnter payment method (Cash or Card): ")

# Printing the bill
print("\n======= BILL =======")
print("Customer Name: " + customer_name)
print("Phone Number: " + phone_number)
print("Items:")

for item in items:
    print(item[0] + " - " + str(item[1]) + " x " + str(item[2]) + " = " + str(item[1] * item[2]))

print("\nSubtotal: " + str(total))
print("Discount: " + str(discount))
print("Total: " + str(final_total))
print("Payment Method: " + payment_method)
print("====================")

print("Thank you for shopping with Supermarket!")

# %%
print("Welcome to Supermarket Billing System!")

# Ask for customer details
customer_name = input("Enter your name: ")
phone_number = input("Enter your phone number: ")
while len(phone_number) != 10 or not phone_number.isdigit():
    print("Please enter a valid 10-digit phone number.")
    phone_number = input("Enter your phone number: ")

# Adding items
print("\nStart entering the items:")
items = []
total = 0

while True:
    item_name = input("Enter item name (or type 'done' to finish): ")
    if item_name.lower() == 'done':
        break
    quantity = int(input("Enter quantity for " + item_name + ": "))
    price = float(input("Enter price for " + item_name + ": "))
    
    items.append([item_name, quantity, price])
    total += quantity * price

# Discount calculation
if total > 1000:
    discount = total * 0.1  # 10% discount
elif total > 500:
    discount = total * 0.05  # 5% discount
else:
    discount = 0

final_total = total - discount

# Ask for payment method
payment_method = input("\nEnter payment method (Cash or Card): ")

# Printing the bill
print("\n======= BILL =======")
print("Customer Name: " + customer_name)
print("Phone Number: " + phone_number)
print("Items:")

for item in items:
    print(item[0] + " - " + str(item[1]) + " x " + str(item[2]) + " = " + str(item[1] * item[2]))

print("\nSubtotal: " + str(total))
print("Discount: " + str(discount))
print("Total: " + str(final_total))
print("Payment Method: " + payment_method)
print("====================")

print("Thank you for shopping with Supermarket!")

# %%
print("Welcome to Supermarket Billing System!")

# Ask for customer details
customer_name = input("Enter your name: ")
phone_number = input("Enter your phone number: ")
while len(phone_number) != 10 or not phone_number.isdigit():
    print("Please enter a valid 10-digit phone number.")
    phone_number = input("Enter your phone number: ")

# Adding items
print("\nStart entering the items:")
items = []
total = 0

while True:
    item_name = input("Enter item name (or type 'done' to finish): ")
    if item_name.lower() == 'done':
        break
    quantity = int(input("Enter quantity for " + item_name + ": "))
    price = float(input("Enter price for " + item_name + ": "))
    
    items.append([item_name, quantity, price])
    total += quantity * price

# Discount calculation
if total > 1000:
    discount = total * 0.1  # 10% discount
elif total > 500:
    discount = total * 0.05  # 5% discount
else:
    discount = 0

final_total = total - discount

# Ask for payment method
payment_method = input("\nEnter payment method (Cash or Card): ")

# Printing the bill
print("\n======= BILL =======")
print("Customer Name: " + customer_name)
print("Phone Number: " + phone_number)
print("Items:")

for item in items:
    print(item[0] + " - " + str(item[1]) + " x " + str(item[2]) + " = " + str(item[1] * item[2]))

print("\nSubtotal: " + str(total))
print("Discount: " + str(discount))
print("Total: " + str(final_total))
print("Payment Method: " + payment_method)
print("====================")

print("Thank you for shopping with Supermarket!")
# Out:
# Welcome to Supermarket Billing System!
# Enter your name:  Sharad
# Enter your phone number:  6376991152
# Start entering the items:
# Enter item name (or type 'done' to finish):  Chips
# Enter quantity for Chips:  2
# Enter price for Chips:  50
# Enter item name (or type 'done' to finish):  Soap
# Enter quantity for Soap:  1
# Enter price for Soap:  20
# Enter item name (or type 'done' to finish):  ToothPaste
# Enter quantity for ToothPaste:  3
# Enter price for ToothPaste:  45
# Enter item name (or type 'done' to finish):  done
#
# Enter payment method (Cash or Card):  cash
# ======= BILL =======
# Customer Name: Sharad
# Phone Number: 6376991152
# Items:
# Chips - 2 x 50.0 = 100.0
# Soap - 1 x 20.0 = 20.0
# ToothPaste - 3 x 45.0 = 135.0
#
# Subtotal: 255.0
# Discount: 0
# Total: 255.0
# Payment Method: cash
# ====================
# Thank you for shopping with Supermarket!
